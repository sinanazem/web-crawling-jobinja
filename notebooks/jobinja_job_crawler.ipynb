# %%
import requests
import time
import threading
from loguru import logger
from pymongo import MongoClient

# Configure logging
def configure_logging():
    logger.add("scraper.log", level="INFO", format="{time} - {level} - {message}")

# Set up MongoDB client and database
def setup_mongo_client():
    client = MongoClient("mongodb://localhost:27017/")
    db = client["scraper_db"]
    collection = db["page_contents"]
    return collection

# Define base URL and headers
base_url = "https://jobinja.ir/companies?page="
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
}

# Function to scrape a single page
def scrape_page(page_number, collection):
    url = base_url + str(page_number)
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raises an HTTPError for bad responses
        page_data = {
            'page_number': page_number,
            'html_content': response.text
        }
        collection.insert_one(page_data)
        logger.info(f"Successfully scraped and stored page {page_number}")
    except requests.exceptions.HTTPError as http_err:
        logger.error(f"HTTP error occurred while scraping page {page_number}: {http_err}")
    except Exception as err:
        logger.error(f"An error occurred while scraping page {page_number}: {err}")

# Function to scrape pages using threading
def scrape_pages_threaded(start_page, end_page, collection, num_threads=10, delay=2):
    def thread_scrape(thread_id, page_range):
        for page_number in page_range:
            scrape_page(page_number, collection)
            time.sleep(delay)  # Sleep to avoid overwhelming the server

    page_ranges = [
        range(start_page + i * (end_page - start_page + 1) // num_threads, 
              start_page + (i + 1) * (end_page - start_page + 1) // num_threads)
        for i in range(num_threads)
    ]

    threads = []
    for i, page_range in enumerate(page_ranges):
        thread = threading.Thread(target=thread_scrape, args=(i, page_range))
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()

# Main function to run the scraper
def run_scraper(start_page, end_page, num_threads=10, delay=2):
    configure_logging()
    collection = setup_mongo_client()
    scrape_pages_threaded(start_page, end_page, collection, num_threads, delay)

# Run the scraper
run_scraper(start_page=1, end_page=10, num_threads=10)
# Out:
# 2024-09-21 05:57:35.951 | INFO     | __main__:scrape_page:35 - Successfully scraped and stored page 4
# 2024-09-21 05:57:35.959 | INFO     | __main__:scrape_page:35 - Successfully scraped and stored page 5
# 2024-09-21 05:57:35.962 | INFO     | __main__:scrape_page:35 - Successfully scraped and stored page 7
# 2024-09-21 05:57:35.963 | INFO     | __main__:scrape_page:35 - Successfully scraped and stored page 9
# 2024-09-21 05:57:35.966 | INFO     | __main__:scrape_page:35 - Successfully scraped and stored page 3
# 2024-09-21 05:57:35.987 | INFO     | __main__:scrape_page:35 - Successfully scraped and stored page 1
# 2024-09-21 05:57:36.007 | INFO     | __main__:scrape_page:35 - Successfully scraped and stored page 2
# 2024-09-21 05:57:36.009 | INFO     | __main__:scrape_page:35 - Successfully scraped and stored page 6
# 2024-09-21 05:57:36.036 | INFO     | __main__:scrape_page:35 - Successfully scraped and stored page 8
# 2024-09-21 05:57:36.500 | INFO     | __main__:scrape_page:35 - Successfully scraped and stored page 10

# %%
from bs4 import BeautifulSoup
from loguru import logger
from pymongo import MongoClient

# Configure logging
def configure_logging():
    logger.add("scraper.log", level="INFO", format="{time} - {level} - {message}")

# Set up MongoDB client and databases
def setup_mongo_client():
    client = MongoClient("mongodb://localhost:27017/")
    db = client["scraper_db"]
    return db

# Function to extract links from HTML content
def extract_links(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    links = [a['href'] for a in soup.find_all('a', href=True, attrs={"class": "c-companyOverview"})]
    return links

# Function to process HTML content and save extracted links to MongoDB
def process_html_content(db):
    collection_html = db["page_contents"]
    collection_links = db["extracted_links"]

    url_results = []
    cursor = collection_html.find()

    for item in cursor:
        page_number = item['page_number']
        html_content = item['html_content']
        links = extract_links(html_content)
        
        url_results.append({
            "page_number": page_number,
            "url_list": links
        })
        logger.info(f"Extracted links on page {page_number}")
        
    # Insert the results into the new collection
    collection_links.insert_many(url_results)
    logger.info(f"All links have been extracted and saved to the database")

# Main function to run the extraction process
def run_extractor():
    configure_logging()
    db = setup_mongo_client()
    process_html_content(db)

# Run the extractor
if __name__ == "__main__":
    run_extractor()
# Out:
# 2024-09-21 05:57:44.076 | INFO     | __main__:process_html_content:38 - Extracted links on page 4
# 2024-09-21 05:57:44.161 | INFO     | __main__:process_html_content:38 - Extracted links on page 5
# 2024-09-21 05:57:44.181 | INFO     | __main__:process_html_content:38 - Extracted links on page 9
# 2024-09-21 05:57:44.204 | INFO     | __main__:process_html_content:38 - Extracted links on page 7
# 2024-09-21 05:57:44.224 | INFO     | __main__:process_html_content:38 - Extracted links on page 3
# 2024-09-21 05:57:44.244 | INFO     | __main__:process_html_content:38 - Extracted links on page 1
# 2024-09-21 05:57:44.263 | INFO     | __main__:process_html_content:38 - Extracted links on page 2
# 2024-09-21 05:57:44.282 | INFO     | __main__:process_html_content:38 - Extracted links on page 6
# 2024-09-21 05:57:44.303 | INFO     | __main__:process_html_content:38 - Extracted links on page 8
# 2024-09-21 05:57:44.322 | INFO     | __main__:process_html_content:38 - Extracted links on page 10
# 2024-09-21 05:57:44.340 | INFO     | __main__:process_html_content:42 - All links have been extracted and saved to the database

# %%
import requests
import json
from concurrent.futures import ThreadPoolExecutor, as_completed
from loguru import logger
from pymongo import MongoClient

# Configure Loguru to write logs to a file
logger.add("script_logs.log", rotation="500 MB")

# Set up MongoDB client and Databases
def setup_mongo_client():
    client = MongoClient("mongodb://localhost:27017/")
    db = client["scraper_db"]
    return db['extracted_links'], db['detailed_pages']

# Function to fetch HTML content
def fetch_html(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
    }
    try:
        response = requests.get(url, headers=headers, allow_redirects=True)
        if response.status_code == 200:
            if response.url.endswith('/jobs'):
                logger.info(f"{url} redirects to /jobs")
            return response.text, response.url
        else:
            logger.error(f"Failed to fetch {url} with status code {response.status_code}")
            return None, url
    except Exception as e:
        logger.error(f"An error occurred while fetching {url}: {e}")
        return None, url

# Function to scrape URL detail pages
def scrape_url_detail_pages(url_list):
    results = []
    with ThreadPoolExecutor(max_workers=10) as executor:
        future_to_url = {executor.submit(fetch_html, url): url for url in url_list}

        for future in as_completed(future_to_url):
            url = future_to_url[future]
            try:
                main_html, actual_url = future.result()
            except Exception as exc:
                logger.error(f"Error fetching {url}: {exc}")
                main_html, actual_url = None, url

            if main_html is None:
                results.append({"url": url, "main_page": {"html_content": ""}, "job_page": {"html_content": ""}, "about_page": {"html_content": ""}})
                continue

            result = {
                "url": url,
                "main_page": {"html_content": main_html if not actual_url.endswith('/jobs') else ""},
                "job_page": {"html_content": main_html if actual_url.endswith('/jobs') else ""},
                "about_page": {"html_content": ""}
            }

            if not actual_url.endswith('/jobs'):
                about_page_url = url + "/about"
                job_page_url = url + "/jobs"

                # Fetch about and jobs pages
                about_html, _ = fetch_html(about_page_url)
                jobs_html, _ = fetch_html(job_page_url)

                result["about_page"]["html_content"] = about_html
                result["job_page"]["html_content"] = jobs_html

            results.append(result)

    logger.info("Scraping completed for the given list of URLs")
    return results

# Function to store results in MongoDB
def store_results_in_mongo(url_detail_pages, collection):
    collection.insert_many(url_detail_pages)
    logger.info(f"Data has been stored in MongoDB")

# Main function to run the extraction process and store data in MongoDB
def run_extractor():
    configure_logging()
    collection_links, collection_pages = setup_mongo_client()

    # Process each document in the collection_links
    cursor = collection_links.find()
    for item in cursor:
        url_list = item['url_list']
        url_detail_pages = scrape_url_detail_pages(url_list)

        store_results_in_mongo(url_detail_pages, collection_pages)

        logger.success(f"Links on page {item['page_number']} have been processed and stored in MongoDB.")

# Function to configure logging
def configure_logging():
    logger.add("scraper.log", level="INFO", format="{time} - {level} - {message}")

# Run the extractor
if __name__ == "__main__":
    run_extractor()
# Out:
# 2024-09-21 05:57:51.418 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/autokhatib/jobs redirects to /jobs
# 2024-09-21 05:57:49.728 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/Dade%20Negar/jobs redirects to /jobs
# 2024-09-21 05:57:50.234 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/ketabemarja/jobs redirects to /jobs
# 2024-09-21 05:57:50.747 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/inoup/jobs redirects to /jobs
# 2024-09-21 05:57:51.330 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/hmpco/jobs redirects to /jobs
# 2024-09-21 05:57:51.897 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/namayandegi-modiran-khodro-sotoodeh401/jobs redirects to /jobs
# 2024-09-21 05:57:52.825 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/minikala/jobs redirects to /jobs
# 2024-09-21 05:57:53.886 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/safarhaye-kish/jobs redirects to /jobs
# 2024-09-21 05:57:53.892 | INFO     | __main__:scrape_url_detail_pages:72 - Scraping completed for the given list of URLs
# 2024-09-21 05:57:53.919 | INFO     | __main__:store_results_in_mongo:78 - Data has been stored in MongoDB
# 2024-09-21 05:57:53.924 | SUCCESS  | __main__:run_extractor:93 - Links on page 4 have been processed and stored in MongoDB.
# 2024-09-21 05:57:55.077 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/setareh-danesh-parsian/jobs redirects to /jobs
# 2024-09-21 05:57:55.633 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/faraz-17/jobs redirects to /jobs
# 2024-09-21 05:57:56.383 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/baman-2/jobs redirects to /jobs
# 2024-09-21 05:57:57.039 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/digitoon/jobs redirects to /jobs
# 2024-09-21 05:57:57.746 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/admoon/jobs redirects to /jobs
# 2024-09-21 05:57:58.404 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/bitbarg/jobs redirects to /jobs
# 2024-09-21 05:57:59.251 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/arka-tejarat/jobs redirects to /jobs
# 2024-09-21 05:57:59.964 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/myarman-1/jobs redirects to /jobs
# 2024-09-21 05:57:59.968 | INFO     | __main__:scrape_url_detail_pages:72 - Scraping completed for the given list of URLs
# 2024-09-21 05:57:59.990 | INFO     | __main__:store_results_in_mongo:78 - Data has been stored in MongoDB
# 2024-09-21 05:57:59.993 | SUCCESS  | __main__:run_extractor:93 - Links on page 5 have been processed and stored in MongoDB.
# 2024-09-21 05:58:00.937 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/vira-security-solutions-2/jobs redirects to /jobs
# 2024-09-21 05:58:01.679 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/afarinesh-holding/jobs redirects to /jobs
# 2024-09-21 05:58:02.612 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/snapp-group-1/jobs redirects to /jobs
# 2024-09-21 05:58:03.380 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/dayangrp/jobs redirects to /jobs
# 2024-09-21 05:58:03.833 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/nebka-1/jobs redirects to /jobs
# 2024-09-21 05:58:04.450 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/triboon/jobs redirects to /jobs
# 2024-09-21 05:58:04.858 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/bitex-1/jobs redirects to /jobs
# 2024-09-21 05:58:05.616 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/goalearn/jobs redirects to /jobs
# 2024-09-21 05:58:05.623 | INFO     | __main__:scrape_url_detail_pages:72 - Scraping completed for the given list of URLs
# 2024-09-21 05:58:05.678 | INFO     | __main__:store_results_in_mongo:78 - Data has been stored in MongoDB
# 2024-09-21 05:58:05.685 | SUCCESS  | __main__:run_extractor:93 - Links on page 9 have been processed and stored in MongoDB.
# 2024-09-21 05:58:06.495 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/abarsayande-1/jobs redirects to /jobs
# 2024-09-21 05:58:06.939 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/zeero/jobs redirects to /jobs
# 2024-09-21 05:58:07.574 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/axon-9/jobs redirects to /jobs
# 2024-09-21 05:58:08.083 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/afaghseir-1/jobs redirects to /jobs
# 2024-09-21 05:58:08.669 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/ramand-computer-group/jobs redirects to /jobs
# 2024-09-21 05:58:09.112 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/rastafann/jobs redirects to /jobs
# 2024-09-21 05:58:09.675 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/bitpin/jobs redirects to /jobs
# 2024-09-21 05:58:10.114 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/ata-tejarat-soloot-1/jobs redirects to /jobs
# 2024-09-21 05:58:10.119 | INFO     | __main__:scrape_url_detail_pages:72 - Scraping completed for the given list of URLs
# 2024-09-21 05:58:10.139 | INFO     | __main__:store_results_in_mongo:78 - Data has been stored in MongoDB
# 2024-09-21 05:58:10.144 | SUCCESS  | __main__:run_extractor:93 - Links on page 7 have been processed and stored in MongoDB.
# 2024-09-21 05:58:10.785 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/medical-strategist/jobs redirects to /jobs
# 2024-09-21 05:58:11.206 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/lenava-engineering-group-ltd/jobs redirects to /jobs
# 2024-09-21 05:58:11.723 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/applyica/jobs redirects to /jobs
# 2024-09-21 05:58:12.163 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/tamironline-1/jobs redirects to /jobs
# 2024-09-21 05:58:12.770 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/bolanda-3/jobs redirects to /jobs
# 2024-09-21 05:58:13.206 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/levants/jobs redirects to /jobs
# 2024-09-21 05:58:13.671 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/dornica-4/jobs redirects to /jobs
# 2024-09-21 05:58:14.446 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/smart-land-optimizers/jobs redirects to /jobs
# 2024-09-21 05:58:14.451 | INFO     | __main__:scrape_url_detail_pages:72 - Scraping completed for the given list of URLs
# 2024-09-21 05:58:14.469 | INFO     | __main__:store_results_in_mongo:78 - Data has been stored in MongoDB
# 2024-09-21 05:58:14.473 | SUCCESS  | __main__:run_extractor:93 - Links on page 3 have been processed and stored in MongoDB.
# 2024-09-21 05:58:15.130 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/dabirestan-neshanerasta/jobs redirects to /jobs
# 2024-09-21 05:58:15.795 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/galaxyvisiontop-gmail-com/jobs redirects to /jobs
# 2024-09-21 05:58:16.288 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/netuarium/jobs redirects to /jobs
# 2024-09-21 05:58:16.725 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/jolfa-1/jobs redirects to /jobs
# 2024-09-21 05:58:17.148 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/boorangroup/jobs redirects to /jobs
# 2024-09-21 05:58:17.593 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/fanhab/jobs redirects to /jobs
# 2024-09-21 05:58:18.006 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/jabama-1/jobs redirects to /jobs
# 2024-09-21 05:58:18.449 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/arzplus-1/jobs redirects to /jobs
# 2024-09-21 05:58:18.453 | INFO     | __main__:scrape_url_detail_pages:72 - Scraping completed for the given list of URLs
# 2024-09-21 05:58:18.468 | INFO     | __main__:store_results_in_mongo:78 - Data has been stored in MongoDB
# 2024-09-21 05:58:18.471 | SUCCESS  | __main__:run_extractor:93 - Links on page 1 have been processed and stored in MongoDB.
# 2024-09-21 05:58:19.076 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/smilinno-innovation-hub/jobs redirects to /jobs
# 2024-09-21 05:58:17.309 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/metazi-group/jobs redirects to /jobs
# 2024-09-21 05:58:17.774 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/adlas/jobs redirects to /jobs
# 2024-09-21 05:58:18.194 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/hesabo/jobs redirects to /jobs
# 2024-09-21 05:58:18.697 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/cippoint/jobs redirects to /jobs
# 2024-09-21 05:58:19.728 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/samanlaya/jobs redirects to /jobs
# 2024-09-21 05:58:20.342 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/ada-company-1/jobs redirects to /jobs
# 2024-09-21 05:58:20.911 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/hitobit/jobs redirects to /jobs
# 2024-09-21 05:58:20.916 | INFO     | __main__:scrape_url_detail_pages:72 - Scraping completed for the given list of URLs
# 2024-09-21 05:58:20.941 | INFO     | __main__:store_results_in_mongo:78 - Data has been stored in MongoDB
# 2024-09-21 05:58:20.946 | SUCCESS  | __main__:run_extractor:93 - Links on page 2 have been processed and stored in MongoDB.
# 2024-09-21 05:58:21.705 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/mazdax/jobs redirects to /jobs
# 2024-09-21 05:58:22.772 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/beroozresaan-2/jobs redirects to /jobs
# 2024-09-21 05:58:23.525 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/baloot-10/jobs redirects to /jobs
# 2024-09-21 05:58:24.184 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/novaday/jobs redirects to /jobs
# 2024-09-21 05:58:24.741 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/sorush-afzar-iranian-1/jobs redirects to /jobs
# 2024-09-21 05:58:25.385 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/dieselirantruck/jobs redirects to /jobs
# 2024-09-21 05:58:26.072 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/noandishan-fanavari-etelaat-alvand/jobs redirects to /jobs
# 2024-09-21 05:58:26.657 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/allin-partners/jobs redirects to /jobs
# 2024-09-21 05:58:26.662 | INFO     | __main__:scrape_url_detail_pages:72 - Scraping completed for the given list of URLs
# 2024-09-21 05:58:26.677 | INFO     | __main__:store_results_in_mongo:78 - Data has been stored in MongoDB
# 2024-09-21 05:58:26.681 | SUCCESS  | __main__:run_extractor:93 - Links on page 6 have been processed and stored in MongoDB.
# 2024-09-21 05:58:27.474 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/novin-dev/jobs redirects to /jobs
# 2024-09-21 05:58:28.123 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/iran-airtour-airlines-1/jobs redirects to /jobs
# 2024-09-21 05:58:28.764 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/ahanresan-2/jobs redirects to /jobs
# 2024-09-21 05:58:29.579 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/daira-hamrah/jobs redirects to /jobs
# 2024-09-21 05:58:29.992 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/safar-touran/jobs redirects to /jobs
# 2024-09-21 05:58:30.558 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/hamrahfelez/jobs redirects to /jobs
# 2024-09-21 05:58:31.061 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/UTTA/jobs redirects to /jobs
# 2024-09-21 05:58:31.697 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/sizpay-1/jobs redirects to /jobs
# 2024-09-21 05:58:31.703 | INFO     | __main__:scrape_url_detail_pages:72 - Scraping completed for the given list of URLs
# 2024-09-21 05:58:31.723 | INFO     | __main__:store_results_in_mongo:78 - Data has been stored in MongoDB
# 2024-09-21 05:58:31.727 | SUCCESS  | __main__:run_extractor:93 - Links on page 8 have been processed and stored in MongoDB.
# 2024-09-21 05:58:32.390 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/aliasys-1/jobs redirects to /jobs
# 2024-09-21 05:58:32.991 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/observation-information-processing-group/jobs redirects to /jobs
# 2024-09-21 05:58:33.495 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/dekamond-tech/jobs redirects to /jobs
# 2024-09-21 05:58:34.067 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/hamtapay-1/jobs redirects to /jobs
# 2024-09-21 05:58:34.541 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/derak-cloud/jobs redirects to /jobs
# 2024-09-21 05:58:34.971 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/danayanpars/jobs redirects to /jobs
# 2024-09-21 05:58:35.468 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/mobonews/jobs redirects to /jobs
# 2024-09-21 05:58:36.164 | INFO     | __main__:fetch_html:25 - https://jobinja.ir/companies/tetherland/jobs redirects to /jobs
# 2024-09-21 05:58:36.169 | INFO     | __main__:scrape_url_detail_pages:72 - Scraping completed for the given list of URLs
# 2024-09-21 05:58:36.189 | INFO     | __main__:store_results_in_mongo:78 - Data has been stored in MongoDB
# 2024-09-21 05:58:36.194 | SUCCESS  | __main__:run_extractor:93 - Links on page 10 have been processed and stored in MongoDB.
